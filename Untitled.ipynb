# %%
import pandas as pd

# %%
df =pd.read_csv('staging_data-1-2017-06-23.csv', encoding="ISO-8859-1")

# %%
df
# Out:
#       Column        Era                                             author  \
# 0        123   Medieval                           Fredegarius Scholasticus
# 1         87   Medieval  [Flavius Valerius Aurelius Constantinus Augustus]
# 2        951  Classical                              [Gaius Iulius Caesar]
# 3        955  Classical                              [Gaius Iulius Caesar]
# 4        964  Classical                              [Gaius Iulius Caesar]
# 5          2   Medieval                                  Abbo Floriacensis
# 6          3   Medieval                                     Adso Dervensis
# 7         86  Classical                                     Aelius Donatus
# 8          4   Medieval                              Aelredus Rievallensis
# 9        309  Neo-Latin                        Aeneas Sylvius Piccolominus
# 10       300  Neo-Latin                        Aeneas Sylvius Piccolominus
# ...

# %%
len(df.filename.unique())
# Out:
# 2053

# %%
df.shape
# Out:
# (2167, 8)

# %%
import esLoad as es

# %%
Filelist =es.getFileList()

# %%
filename = 'q1.17.txt'
indices = [i for i, x in enumerate(Filelist) if filename in x ]

# %%
indices
# Out:
# [663]

# %%
Filelist[indices[0]]
# Out:
# './aquinas/q1.17.txt'
